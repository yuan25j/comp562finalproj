# %%
import pandas as pd
initial_df = pd.read_csv('Collisions.csv')

df = pd.DataFrame()
wanted_columns = ['X', 'Y', 'ADDRTYPE','SEVERITYCODE', 'VEHCOUNT', 'INJURIES', 'SERIOUSINJURIES', 
                  'FATALITIES', 'JUNCTIONTYPE', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'ST_COLCODE']
for c in wanted_columns:
         df[str(c)] = initial_df[c]
df.to_csv("SelectedColCollisions.csv", index=False)
# Out:
#             X          Y      ADDRTYPE SEVERITYCODE  VEHCOUNT  INJURIES  \
# 0 -122.386772  47.564720  Intersection            2         1         1
# 1 -122.341806  47.686934  Intersection            2         2         2
# 2 -122.374899  47.668666         Block            1         3         0
# 3 -122.300758  47.683047  Intersection            1         2         0
# 4 -122.313053  47.567241         Block            0         0         0
#
#    SERIOUSINJURIES  FATALITIES                             JUNCTIONTYPE  \
# 0                0           0   At Intersection (intersection related)
# 1                0           0   At Intersection (intersection related)
# 2                0           0  Mid-Block (not related to intersection)
# 3                0           0   At Intersection (intersection related)
# 4                0           0     Mid-Block (but intersection related)
#
#   UNDERINFL  WEATHER ROADCOND                LIGHTCOND ST_COLCODE
# 0         N    Clear      Dry                 Daylight          2
# 1         N  Raining      Wet  Dark - Street Lights On         10
# 2         N    Clear      Dry                 Daylight         11
# 3         0  Raining      Wet  Dark - Street Lights On         28
# 4       NaN      NaN      NaN                      NaN        NaN
